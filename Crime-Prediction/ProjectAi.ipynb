# %% [markdown]
# # Importing

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Gui
import joblib
import tkinter as tk
from tkinter import ttk
from tkcalendar import DateEntry
from datetime import datetime

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
# Bounus
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,classification_report, confusion_matrix, roc_auc_score

# %% [markdown]
# # Data Inspection

# %%
df = pd.read_csv("Crime Prediction in Chicago_Dataset.csv")
df.head(10).T
# Out:
#                                                    0  \
# ID                                          12592454
# Case Number                                 JF113025
# Date                                 1/14/2022 15:55
# Block                              067XX S MORGAN ST
# IUCR                                            2826
# Primary Type                           OTHER OFFENSE
# Description           HARASSMENT BY ELECTRONIC MEANS
# Location Description                       RESIDENCE
# Arrest                                         False
# Domestic                                        True
# Beat                                             724
# District                                           7
# Ward                                            16.0
# Community Area                                    68
# FBI Code                                          26
# X Coordinate                               1170805.0
# Y Coordinate                               1860170.0
# Year                                            2022
# Updated On                           9/14/2023 15:41
# Latitude                                   41.771782
# Longitude                                 -87.649437
# Location               (41.771782439, -87.649436929)
#
#                                                    1  \
# ID                                          12785595
# Case Number                                 JF346553
# Date                                  8/5/2022 21:00
# Block                         072XX S UNIVERSITY AVE
# IUCR                                            1544
# Primary Type                             SEX OFFENSE
# Description           SEXUAL EXPLOITATION OF A CHILD
# Location Description                       APARTMENT
# Arrest                                          True
# Domestic                                       False
# Beat                                             324
# District                                           3
# Ward                                             5.0
# Community Area                                    69
# FBI Code                                          17
# X Coordinate                               1185135.0
# Y Coordinate                               1857211.0
# Year                                            2022
# Updated On                           9/14/2023 15:41
# Latitude                                   41.763338
# Longitude                                 -87.597001
# Location               (41.763337967, -87.597001131)
#
#                                                      2  \
# ID                                            12808281
# Case Number                                   JF373517
# Date                                   8/14/2022 14:00
# Block                              055XX W ARDMORE AVE
# IUCR                                              1562
# Primary Type                               SEX OFFENSE
# Description           AGGRAVATED CRIMINAL SEXUAL ABUSE
# Location Description                         RESIDENCE
# Arrest                                           False
# Domestic                                         False
# Beat                                              1621
# District                                            16
# Ward                                              39.0
# Community Area                                      11
# FBI Code                                            17
# X Coordinate                                 1138383.0
# Y Coordinate                                 1937953.0
# Year                                              2022
# Updated On                             9/14/2023 15:41
# Latitude                                     41.985875
# Longitude                                   -87.766404
# Location                 (41.985875279, -87.766403857)
#
#                                                  3  \
# ID                                        12888104
# Case Number                               JF469015
# Date                               11/10/2022 3:47
# Block                               072XX S MAY ST
# IUCR                                          1477
# Primary Type                     WEAPONS VIOLATION
# Description             RECKLESS FIREARM DISCHARGE
# Location Description                        STREET
# Arrest                                       False
# Domestic                                     False
# Beat                                           733
# District                                         7
# Ward                                          17.0
# Community Area                                  68
# FBI Code                                        15
# X Coordinate                             1169903.0
# Y Coordinate                             1856822.0
# Year                                          2022
# Updated On                         9/14/2023 15:41
# Latitude                                 41.762615
# Longitude                                -87.65284
# Location              (41.76261474, -87.652840463)
#
#                                                  4  \
# ID                                        13209277
# Case Number                               JG422539
# Date                                8/15/2022 9:00
# Block                         0000X W JACKSON BLVD
# IUCR                                           810
# Primary Type                                 THEFT
# Description                              OVER $500
# Location Description  COMMERCIAL / BUSINESS OFFICE
# Arrest                                       False
# Domestic                                     False
# Beat                                           113
# District                                         1
# Ward                                           4.0
# Community Area                                  32
# FBI Code                                         6
# X Coordinate                                   NaN
# Y Coordinate                                   NaN
# Year                                          2022
# Updated On                         9/14/2023 15:43
# Latitude                                       NaN
# Longitude                                      NaN
# Location                                       NaN
#
#                                                   5  \
# ID                                         12622465
# Case Number                                JF149923
# Date                                2/19/2022 10:36
# Block                         010XX N FRANCISCO AVE
# IUCR                                            486
# Primary Type                                BATTERY
# Description                 DOMESTIC BATTERY SIMPLE
# Location Description    HOSPITAL BUILDING / GROUNDS
# Arrest                                         True
# Domestic                                       True
# Beat                                           1211
# District                                         12
# Ward                                           26.0
# Community Area                                   24
# FBI Code                                        08B
# X Coordinate                              1156861.0
# Y Coordinate                              1906972.0
# Year                                           2022
# Updated On                          9/15/2023 15:41
# Latitude                                  41.900506
# Longitude                                -87.699285
# Location              (41.900505589, -87.699285044)
#
#                                                  6  \
# ID                                        12640859
# Case Number                               JF172230
# Date                                3/13/2022 5:15
# Block                           012XX W PRATT BLVD
# IUCR                                           486
# Primary Type                               BATTERY
# Description                DOMESTIC BATTERY SIMPLE
# Location Description                     RESIDENCE
# Arrest                                        True
# Domestic                                      True
# Beat                                          2431
# District                                        24
# Ward                                          49.0
# Community Area                                   1
# FBI Code                                       08B
# X Coordinate                             1166646.0
# Y Coordinate                             1945317.0
# Year                                          2022
# Updated On                         9/15/2023 15:41
# Latitude                                 42.005522
# Longitude                               -87.662241
# Location              (42.00552183, -87.662241448)
#
#                                                   7  \
# ID                                         12667337
# Case Number                                JF203985
# Date                                4/10/2022 21:38
# Block                            011XX N CHERRY AVE
# IUCR                                           4387
# Primary Type                          OTHER OFFENSE
# Description             VIOLATE ORDER OF PROTECTION
# Location Description                      WAREHOUSE
# Arrest                                         True
# Domestic                                       True
# Beat                                           1822
# District                                         18
# Ward                                           27.0
# Community Area                                    8
# FBI Code                                         26
# X Coordinate                              1169620.0
# Y Coordinate                              1907431.0
# Year                                           2022
# Updated On                          9/15/2023 15:41
# Latitude                                  41.901497
# Longitude                                -87.652407
# Location              (41.901496787, -87.652407386)
#
#                                                   8  \
# ID                                         12671049
# Case Number                                JF208259
# Date                                4/14/2022 22:10
# Block                               003XX E OHIO ST
# IUCR                                            486
# Primary Type                                BATTERY
# Description                 DOMESTIC BATTERY SIMPLE
# Location Description           VEHICLE - COMMERCIAL
# Arrest                                         True
# Domestic                                       True
# Beat                                           1834
# District                                         18
# Ward                                            2.0
# Community Area                                    8
# FBI Code                                        08B
# X Coordinate                              1178915.0
# Y Coordinate                              1904276.0
# Year                                           2022
# Updated On                          9/15/2023 15:41
# Latitude                                  41.892632
# Longitude                                -87.618363
# Location              (41.892631803, -87.618362824)
#
#                                                 9
# ID                                       12678035
# Case Number                              JF216671
# Date                              4/22/2022 23:30
# Block                            044XX N BROADWAY
# IUCR                                          810
# Primary Type                                THEFT
# Description                             OVER $500
# Location Description                    APARTMENT
# Arrest                                       True
# Domestic                                     True
# Beat                                         1914
# District                                       19
# Ward                                         46.0
# Community Area                                  3
# FBI Code                                        6
# X Coordinate                            1168614.0
# Y Coordinate                            1929562.0
# Year                                         2022
# Updated On                        9/15/2023 15:41
# Latitude                                41.962247
# Longitude                               -87.65546
# Location              (41.962247182, -87.6554598)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239558 entries, 0 to 239557
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    239558 non-null  int64
#  1   Case Number           239558 non-null  object
#  2   Date                  239558 non-null  object
#  3   Block                 239558 non-null  object
#  4   IUCR                  239558 non-null  object
#  5   Primary Type          239558 non-null  object
#  6   Description           239558 non-null  object
#  7   Location Description  238593 non-null  object
#  8   Arrest                239558 non-null  bool
#  9   Domestic              239558 non-null  bool
#  10  Beat                  239558 non-null  int64
#  11  District              239558 non-null  int64
#  12  Ward                  239548 non-null  float64
#  13  Community Area        239558 non-null  int64
#  14  FBI Code              239558 non-null  object
#  15  X Coordinate          234891 non-null  float64
#  16  Y Coordinate          234891 non-null  float64
#  17  Year                  239558 non-null  int64
#  18  Updated On            239558 non-null  object
#  19  Latitude              234891 non-null  float64
#  20  Longitude             234891 non-null  float64
#  21  Location              234891 non-null  object
# dtypes: bool(2), float64(5), int64(5), object(10)
# memory usage: 37.0+ MB

# %% [markdown]
# # Data Cleaning

# %%
df.isnull().sum()
# Out:
# ID                         0
# Case Number                0
# Date                       0
# Block                      0
# IUCR                       0
# Primary Type               0
# Description                0
# Location Description     965
# Arrest                     0
# Domestic                   0
# Beat                       0
# District                   0
# Ward                      10
# Community Area             0
# FBI Code                   0
# X Coordinate            4667
# Y Coordinate            4667
# Year                       0
# Updated On                 0
# Latitude                4667
# Longitude               4667
# Location                4667
# dtype: int64

# %% [markdown]
# - Missing locations

# %% [markdown]
# ### Fill Location Description with the most frequent value as its a large dataset

# %%
df['Location Description'].value_counts().head(10)
# Out:
# Location Description
# STREET                                    67640
# APARTMENT                                 45748
# RESIDENCE                                 30603
# SIDEWALK                                  12059
# PARKING LOT / GARAGE (NON RESIDENTIAL)     9333
# SMALL RETAIL STORE                         7261
# ALLEY                                      5019
# RESTAURANT                                 4867
# OTHER (SPECIFY)                            3629
# COMMERCIAL / BUSINESS OFFICE               3599
# Name: count, dtype: int64

# %%
df['Location Description'] = df['Location Description'].fillna(df['Location Description'].mode()[0])

# %%
df.isnull().sum()
# Out:
# ID                         0
# Case Number                0
# Date                       0
# Block                      0
# IUCR                       0
# Primary Type               0
# Description                0
# Location Description       0
# Arrest                     0
# Domestic                   0
# Beat                       0
# District                   0
# Ward                      10
# Community Area             0
# FBI Code                   0
# X Coordinate            4667
# Y Coordinate            4667
# Year                       0
# Updated On                 0
# Latitude                4667
# Longitude               4667
# Location                4667
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df_null_ward = df[df.Ward.isnull()]

# %%
df_null_ward.T
# Out:
#                                              4789    \
# ID                                         12609276
# Case Number                                JF133579
# Date                                 2/4/2022 11:50
# Block                             017XX W HOWARD ST
# IUCR                                           2027
# Primary Type                              NARCOTICS
# Description                         POSSESS - CRACK
# Location Description                         STREET
# Arrest                                         True
# Domestic                                      False
# Beat                                           2422
# District                                         24
# Ward                                            NaN
# Community Area                                    1
# FBI Code                                         18
# X Coordinate                              1163643.0
# Y Coordinate                              1950346.0
# Year                                           2022
# Updated On                           1/3/2023 15:40
# Latitude                                  42.019386
# Longitude                                -87.673147
# Location              (42.019385566, -87.673147017)
#
#                                              17628   \
# ID                                         12582537
# Case Number                                JF100732
# Date                                 1/1/2022 10:00
# Block                             017XX W HOWARD ST
# IUCR                                            281
# Primary Type                CRIMINAL SEXUAL ASSAULT
# Description                          NON-AGGRAVATED
# Location Description                          ALLEY
# Arrest                                        False
# Domestic                                      False
# Beat                                           2422
# District                                         24
# Ward                                            NaN
# Community Area                                    1
# FBI Code                                          2
# X Coordinate                              1163643.0
# Y Coordinate                              1950346.0
# Year                                           2022
# Updated On                           1/3/2023 15:40
# Latitude                                  42.019386
# Longitude                                -87.673147
# Location              (42.019385566, -87.673147017)
#
#                                              48471   \
# ID                                         12642864
# Case Number                                JF174518
# Date                                  3/5/2022 0:00
# Block                             017XX W HOWARD ST
# IUCR                                            870
# Primary Type                                  THEFT
# Description                          POCKET-PICKING
# Location Description                      CTA TRAIN
# Arrest                                        False
# Domestic                                      False
# Beat                                           2422
# District                                         24
# Ward                                            NaN
# Community Area                                    1
# FBI Code                                          6
# X Coordinate                              1163643.0
# Y Coordinate                              1950346.0
# Year                                           2022
# Updated On                           1/3/2023 15:40
# Latitude                                  42.019386
# Longitude                                -87.673147
# Location              (42.019385566, -87.673147017)
#
#                                               55792   \
# ID                                          12761006
# Case Number                                 JF317384
# Date                                 7/14/2022 11:12
# Block                               007XX W OHARE ST
# IUCR                                            143A
# Primary Type                       WEAPONS VIOLATION
# Description            UNLAWFUL POSSESSION - HANDGUN
# Location Description  AIRPORT EXTERIOR - SECURE AREA
# Arrest                                          True
# Domestic                                       False
# Beat                                            1654
# District                                          16
# Ward                                             NaN
# Community Area                                    76
# FBI Code                                          15
# X Coordinate                               1094587.0
# Y Coordinate                               1945065.0
# Year                                            2022
# Updated On                            1/3/2023 15:40
# Latitude                                   42.006074
# Longitude                                 -87.927365
# Location               (42.006074109, -87.927364891)
#
#                                              84053   \
# ID                                         12636585
# Case Number                                JF167177
# Date                                 3/6/2022 19:00
# Block                             017XX W HOWARD ST
# IUCR                                            810
# Primary Type                                  THEFT
# Description                               OVER $500
# Location Description                         STREET
# Arrest                                        False
# Domestic                                      False
# Beat                                           2422
# District                                         24
# Ward                                            NaN
# Community Area                                    1
# FBI Code                                          6
# X Coordinate                              1163643.0
# Y Coordinate                              1950346.0
# Year                                           2022
# Updated On                           1/3/2023 15:40
# Latitude                                  42.019386
# Longitude                                -87.673147
# Location              (42.019385566, -87.673147017)
#
#                                              85064   \
# ID                                         12828085
# Case Number                                JF396056
# Date                                 9/14/2022 9:00
# Block                            065XX N HARLEM AVE
# IUCR                                           1120
# Primary Type                     DECEPTIVE PRACTICE
# Description                                 FORGERY
# Location Description                      APARTMENT
# Arrest                                        False
# Domestic                                      False
# Beat                                           1611
# District                                         16
# Ward                                            NaN
# Community Area                                   10
# FBI Code                                         10
# X Coordinate                              1127377.0
# Y Coordinate                              1943043.0
# Year                                           2022
# Updated On                           1/3/2023 15:40
# Latitude                                  42.000036
# Longitude                                -87.806769
# Location              (42.000035501, -87.806769117)
#
#                                              95081   \
# ID                                         12816101
# Case Number                                JF382023
# Date                                 9/3/2022 18:45
# Block                            065XX N HARLEM AVE
# IUCR                                            560
# Primary Type                                ASSAULT
# Description                                  SIMPLE
# Location Description                      APARTMENT
# Arrest                                        False
# Domestic                                      False
# Beat                                           1611
# District                                         16
# Ward                                            NaN
# Community Area                                   10
# FBI Code                                        08A
# X Coordinate                              1127377.0
# Y Coordinate                              1943043.0
# Year                                           2022
# Updated On                           1/3/2023 15:40
# Latitude                                  42.000036
# Longitude                                -87.806769
# Location              (42.000035501, -87.806769117)
#
#                                                  131756  \
# ID                                             12631631
# Case Number                                    JF161173
# Date                                     3/2/2022 16:15
# Block                                  007XX W OHARE ST
# IUCR                                               1478
# Primary Type          CONCEALED CARRY LICENSE VIOLATION
# Description                           PROHIBITED PLACES
# Location Description     AIRPORT EXTERIOR - SECURE AREA
# Arrest                                             True
# Domestic                                          False
# Beat                                               1654
# District                                             16
# Ward                                                NaN
# Community Area                                       76
# FBI Code                                             15
# X Coordinate                                  1094587.0
# Y Coordinate                                  1945065.0
# Year                                               2022
# Updated On                               1/3/2023 15:40
# Latitude                                      42.006074
# Longitude                                    -87.927365
# Location                  (42.006074109, -87.927364891)
#
#                                              137055  \
# ID                                         12794589
# Case Number                                JF357286
# Date                                 8/15/2022 9:50
# Block                             017XX W HOWARD ST
# IUCR                                            460
# Primary Type                                BATTERY
# Description                                  SIMPLE
# Location Description                         STREET
# Arrest                                        False
# Domestic                                      False
# Beat                                           2422
# District                                         24
# Ward                                            NaN
# Community Area                                    1
# FBI Code                                        08B
# X Coordinate                              1163643.0
# Y Coordinate                              1950346.0
# Year                                           2022
# Updated On                           1/3/2023 15:40
# Latitude                                  42.019386
# Longitude                                -87.673147
# Location              (42.019385566, -87.673147017)
#
#                                                    209086
# ID                                               12857345
# Case Number                                      JF431502
# Date                                       9/12/2022 2:08
# Block                                056XX N FAIRVIEW AVE
# IUCR                                                 1153
# Primary Type                           DECEPTIVE PRACTICE
# Description           FINANCIAL IDENTITY THEFT OVER $ 300
# Location Description                               STREET
# Arrest                                              False
# Domestic                                            False
# Beat                                                 1614
# District                                               16
# Ward                                                  NaN
# Community Area                                         10
# FBI Code                                               11
# X Coordinate                                          NaN
# Y Coordinate                                          NaN
# Year                                                 2022
# Updated On                               10/13/2022 15:42
# Latitude                                              NaN
# Longitude                                             NaN
# Location                                              NaN

# %%
df_null_ward['District']
# Out:
# 4789      24
# 17628     24
# 48471     24
# 55792     16
# 84053     24
# 85064     16
# 95081     16
# 131756    16
# 137055    24
# 209086    16
# Name: District, dtype: int64

# %%
df2 = df[df['District']==24]
df2['Ward'].describe()
# Out:
# count    8487.000000
# mean       48.365382
# std         2.807181
# min        40.000000
# 25%        49.000000
# 50%        49.000000
# 75%        50.000000
# max        50.000000
# Name: Ward, dtype: float64

# %%
df2 = df[df['District']==16]
df2['Ward'].describe()
# Out:
# count    9261.000000
# mean       39.865025
# std         3.972411
# min        29.000000
# 25%        38.000000
# 50%        41.000000
# 75%        41.000000
# max        45.000000
# Name: Ward, dtype: float64

# %% [markdown]
# ### Set the missing ward based on the district as there is good relationship bet them

# %%
df.loc[df['District'] == 24, 'Ward'] = 49
df.loc[df['District'] == 16, 'Ward'] = 41

# %%
df.isnull().sum()
# Out:
# ID                         0
# Case Number                0
# Date                       0
# Block                      0
# IUCR                       0
# Primary Type               0
# Description                0
# Location Description       0
# Arrest                     0
# Domestic                   0
# Beat                       0
# District                   0
# Ward                       0
# Community Area             0
# FBI Code                   0
# X Coordinate            4667
# Y Coordinate            4667
# Year                       0
# Updated On                 0
# Latitude                4667
# Longitude               4667
# Location                4667
# dtype: int64

# %%
df.dropna(subset=['X Coordinate'], inplace=True)

# %%
df.isnull().sum()
# Out:
# ID                      0
# Case Number             0
# Date                    0
# Block                   0
# IUCR                    0
# Primary Type            0
# Description             0
# Location Description    0
# Arrest                  0
# Domestic                0
# Beat                    0
# District                0
# Ward                    0
# Community Area          0
# FBI Code                0
# X Coordinate            0
# Y Coordinate            0
# Year                    0
# Updated On              0
# Latitude                0
# Longitude               0
# Location                0
# dtype: int64

# %% [markdown]
# - No nulls

# %% [markdown]
# # EDA

# %% [markdown]
# ## Univariant Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 234891 entries, 0 to 239557
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    234891 non-null  int64
#  1   Case Number           234891 non-null  object
#  2   Date                  234891 non-null  object
#  3   Block                 234891 non-null  object
#  4   IUCR                  234891 non-null  object
#  5   Primary Type          234891 non-null  object
#  6   Description           234891 non-null  object
#  7   Location Description  234891 non-null  object
#  8   Arrest                234891 non-null  bool
#  9   Domestic              234891 non-null  bool
#  10  Beat                  234891 non-null  int64
#  11  District              234891 non-null  int64
#  12  Ward                  234891 non-null  float64
#  13  Community Area        234891 non-null  int64
#  14  FBI Code              234891 non-null  object
#  15  X Coordinate          234891 non-null  float64
#  16  Y Coordinate          234891 non-null  float64
#  17  Year                  234891 non-null  int64
#  18  Updated On            234891 non-null  object
#  19  Latitude              234891 non-null  float64
#  20  Longitude             234891 non-null  float64
#  21  Location              234891 non-null  object
# dtypes: bool(2), float64(5), int64(5), object(10)
# memory usage: 38.1+ MB

# %%
df.Date
# Out:
# 0         1/14/2022 15:55
# 1          8/5/2022 21:00
# 2         8/14/2022 14:00
# 3         11/10/2022 3:47
# 5         2/19/2022 10:36
#                ...
# 239553     9/8/2022 10:50
# 239554    6/10/2022 23:41
# 239555     2/3/2022 16:27
# 239556     6/23/2022 2:25
# 239557     8/31/2022 9:30
# Name: Date, Length: 234891, dtype: object

# %%
df.Block.value_counts().head(10)
# Out:
# Block
# 001XX N STATE ST       593
# 0000X W TERMINAL ST    555
# 100XX W OHARE ST       315
# 003XX E RANDOLPH ST    300
# 0000X N STATE ST       260
# 0000X E GRAND AVE      257
# 012XX S WABASH AVE     251
# 026XX N CLARK ST       240
# 057XX S CICERO AVE     225
# 002XX E HURON ST       216
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 234891 entries, 0 to 239557
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    234891 non-null  int64
#  1   Case Number           234891 non-null  object
#  2   Date                  234891 non-null  object
#  3   Block                 234891 non-null  object
#  4   IUCR                  234891 non-null  object
#  5   Primary Type          234891 non-null  object
#  6   Description           234891 non-null  object
#  7   Location Description  234891 non-null  object
#  8   Arrest                234891 non-null  bool
#  9   Domestic              234891 non-null  bool
#  10  Beat                  234891 non-null  int64
#  11  District              234891 non-null  int64
#  12  Ward                  234891 non-null  float64
#  13  Community Area        234891 non-null  int64
#  14  FBI Code              234891 non-null  object
#  15  X Coordinate          234891 non-null  float64
#  16  Y Coordinate          234891 non-null  float64
#  17  Year                  234891 non-null  int64
#  18  Updated On            234891 non-null  object
#  19  Latitude              234891 non-null  float64
#  20  Longitude             234891 non-null  float64
#  21  Location              234891 non-null  object
# dtypes: bool(2), float64(5), int64(5), object(10)
# memory usage: 38.1+ MB

# %%
df['IUCR'].value_counts().head(10)
# Out:
# IUCR
# 810     19674
# 486     18636
# 820     18533
# 910     17087
# 1320    14103
# 460     13644
# 560     13150
# 1310    12101
# 860      8572
# 143A     5395
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 234891 entries, 0 to 239557
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    234891 non-null  int64
#  1   Case Number           234891 non-null  object
#  2   Date                  234891 non-null  object
#  3   Block                 234891 non-null  object
#  4   IUCR                  234891 non-null  object
#  5   Primary Type          234891 non-null  object
#  6   Description           234891 non-null  object
#  7   Location Description  234891 non-null  object
#  8   Arrest                234891 non-null  bool
#  9   Domestic              234891 non-null  bool
#  10  Beat                  234891 non-null  int64
#  11  District              234891 non-null  int64
#  12  Ward                  234891 non-null  float64
#  13  Community Area        234891 non-null  int64
#  14  FBI Code              234891 non-null  object
#  15  X Coordinate          234891 non-null  float64
#  16  Y Coordinate          234891 non-null  float64
#  17  Year                  234891 non-null  int64
#  18  Updated On            234891 non-null  object
#  19  Latitude              234891 non-null  float64
#  20  Longitude             234891 non-null  float64
#  21  Location              234891 non-null  object
# dtypes: bool(2), float64(5), int64(5), object(10)
# memory usage: 38.1+ MB

# %%
count_prim = df['Primary Type'].value_counts().head(15)
count_prim
# Out:
# Primary Type
# THEFT                         53625
# BATTERY                       40806
# CRIMINAL DAMAGE               27028
# MOTOR VEHICLE THEFT           21386
# ASSAULT                       20738
# DECEPTIVE PRACTICE            15371
# OTHER OFFENSE                 14371
# ROBBERY                        8953
# WEAPONS VIOLATION              8710
# BURGLARY                       7564
# CRIMINAL TRESPASS              4202
# NARCOTICS                      4037
# OFFENSE INVOLVING CHILDREN     1764
# CRIMINAL SEXUAL ASSAULT        1486
# SEX OFFENSE                    1138
# Name: count, dtype: int64

# %%
plt.style.use("fivethirtyeight")
plt.figure(figsize=(8,5))
sns.barplot(y=count_prim.index,x=count_prim.values,palette="viridis")
plt.title("TOP 15 Primary Types")
plt.ylabel("Types")
plt.xlabel("count")
plt.show()
# Out:
# C:\Users\abdel\AppData\Local\Temp\ipykernel_4668\3289201796.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=count_prim.index,x=count_prim.values,palette="viridis")

# %%
count_Des = df['Description'].value_counts().head(10)
count_Des
# Out:
# Description
# SIMPLE                           27089
# OVER $500                        19674
# DOMESTIC BATTERY SIMPLE          18636
# $500 AND UNDER                   18533
# AUTOMOBILE                       17087
# TO VEHICLE                       14673
# TO PROPERTY                      12101
# RETAIL THEFT                      8572
# AGGRAVATED - HANDGUN              6807
# UNLAWFUL POSSESSION - HANDGUN     5395
# Name: count, dtype: int64

# %%
plt.style.use("fivethirtyeight")
plt.figure(figsize=(6,4))
sns.barplot(y=count_Des.index,x=count_Des.values,palette="viridis")
plt.title("TOP 5 Descriprtion")
plt.ylabel("Description")
plt.xlabel("count")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\abdel\AppData\Local\Temp\ipykernel_4668\2023226518.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=count_Des.index,x=count_Des.values,palette="viridis")

# %%
count = df['Arrest'].value_counts()
percentage = df['Arrest'].value_counts(normalize=True)*100
freqTable = pd.DataFrame({'Frequency':count,'Percentage':percentage})
freqTable
# Out:
#         Frequency  Percentage
# Arrest
# False      211505   88.289684
# True        28053   11.710316

# %% [markdown]
# Imbalane in Arrest column  (False class > True class)
# - which can lead to models that are biased toward the False class, resulting poor preditive performance for the True class.

# %%
plt.figure(figsize=(8, 4))
sns.heatmap(freqTable.T, annot=True, fmt=".1f", cmap="YlGnBu", cbar=False)
plt.title("Arrest")
plt.xlabel('')
plt.show()

# %%
count_dom = df['Domestic'].value_counts()
count_dom
# Out:
# Domestic
# False    190348
# True      44543
# Name: count, dtype: int64

# %%
# Pie Chart
plt.style.use("ggplot")
plt.figure(figsize=(6, 6))
plt.pie(count, labels=count.index, autopct='%1.1f%%', startangle=90,textprops={"fontweight":"black"},explode=[0, 0.1])
plt.title("Arrest")
plt.legend()
plt.show()

# %%
df['Beat'].value_counts()
# Out:
# Beat
# 1834    3024
# 123     2082
# 421     2057
# 1831    1863
# 423     1752
#         ...
# 1813     331
# 1654     303
# 1653     205
# 1655     118
# 1652      91
# Name: count, Length: 274, dtype: int64

# %%
df['District'].value_counts()
# Out:
# District
# 8     14629
# 6     14578
# 12    14087
# 4     13811
# 11    13009
# 1     12652
# 18    12142
# 19    11934
# 3     11816
# 25    11792
# 2     11629
# 9     10260
# 7     10229
# 10     9850
# 5      9697
# 16     8872
# 24     8329
# 15     8234
# 14     7980
# 22     7578
# 17     6904
# 20     4864
# 31       15
# Name: count, dtype: int64

# %%
df['Ward'].value_counts().head(20)
# Out:
# Ward
# 42.0    12338
# 27.0    10925
# 28.0     9918
# 41.0     8880
# 6.0      8504
# 49.0     8329
# 24.0     8012
# 4.0      7641
# 7.0      7508
# 8.0      7356
# 3.0      7341
# 21.0     7266
# 20.0     7248
# 9.0      6745
# 17.0     6650
# 5.0      6070
# 37.0     5934
# 34.0     5919
# 16.0     5888
# 25.0     5362
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 234891 entries, 0 to 239557
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    234891 non-null  int64
#  1   Case Number           234891 non-null  object
#  2   Date                  234891 non-null  object
#  3   Block                 234891 non-null  object
#  4   IUCR                  234891 non-null  object
#  5   Primary Type          234891 non-null  object
#  6   Description           234891 non-null  object
#  7   Location Description  234891 non-null  object
#  8   Arrest                234891 non-null  bool
#  9   Domestic              234891 non-null  bool
#  10  Beat                  234891 non-null  int64
#  11  District              234891 non-null  int64
#  12  Ward                  234891 non-null  float64
#  13  Community Area        234891 non-null  int64
#  14  FBI Code              234891 non-null  object
#  15  X Coordinate          234891 non-null  float64
#  16  Y Coordinate          234891 non-null  float64
#  17  Year                  234891 non-null  int64
#  18  Updated On            234891 non-null  object
#  19  Latitude              234891 non-null  float64
#  20  Longitude             234891 non-null  float64
#  21  Location              234891 non-null  object
# dtypes: bool(2), float64(5), int64(5), object(10)
# memory usage: 38.1+ MB

# %%
df['Community Area'].value_counts().head(10)
# Out:
# Community Area
# 25    12122
# 8     10350
# 28     9301
# 43     8237
# 32     7791
# 24     7080
# 29     6539
# 71     6228
# 23     6026
# 44     6024
# Name: count, dtype: int64

# %%
df['FBI Code'].value_counts()
# Out:
# FBI Code
# 6      53625
# 08B    33828
# 14     27028
# 7      21386
# 08A    17458
# 26     15400
# 11     12844
# 3       8953
# 15      8892
# 5       7564
# 04B     7474
# 04A     7268
# 18      4040
# 10      2430
# 2       1681
# 17      1538
# 24      1084
# 01A      725
# 20       652
# 9        421
# 16       283
# 22       203
# 13        75
# 12        22
# 19        10
# 01B        7
# Name: count, dtype: int64

# %%
df = df.drop(columns=['Year','Location'])

# %% [markdown]
# - Year has value 2022 only
# - Location has the same value of longitude and latitude

# %% [markdown]
# ## Bivariant Analysis

# %%
df.groupby(['IUCR', 'Primary Type', 'FBI Code']).size().head(20)
# Out:
# IUCR  Primary Type        FBI Code
# 031A  ROBBERY             3           3561
# 031B  ROBBERY             3             70
# 033A  ROBBERY             3            348
# 033B  ROBBERY             3             17
# 041A  BATTERY             04B         2106
# 041B  BATTERY             04B           11
# 051A  ASSAULT             04A         4643
# 051B  ASSAULT             04A          148
# 1010  ARSON               9              9
# 1020  ARSON               9            332
# 1025  ARSON               9             35
# 1030  ARSON               9              4
# 1050  HUMAN TRAFFICKING   26             6
# 1055  HUMAN TRAFFICKING   26             2
# 1090  ARSON               9             41
# 110   HOMICIDE            01A          724
# 1110  DECEPTIVE PRACTICE  11           614
# 1120  DECEPTIVE PRACTICE  10          1901
# 1121  DECEPTIVE PRACTICE  10           200
# 1122  DECEPTIVE PRACTICE  10           329
# dtype: int64

# %%
df.groupby(['Primary Type'])['Description'].value_counts().head(50)
# Out:
# Primary Type                       Description
# ARSON                              BY FIRE                                                           332
#                                    ATTEMPT ARSON                                                      41
#                                    AGGRAVATED                                                         35
#                                    BY EXPLOSIVE                                                        9
#                                    POSSESSION - EXPLOSIVE / INCENDIARY DEVICE                          4
# ASSAULT                            SIMPLE                                                          13150
#                                    AGGRAVATED - HANDGUN                                             4643
#                                    AGGRAVATED - KNIFE / CUTTING INSTRUMENT                          1331
#                                    AGGRAVATED - OTHER DANGEROUS WEAPON                               974
#                                    PROTECTED EMPLOYEE - HANDS, FISTS, FEET, NO / MINOR INJURY        226
#                                    AGGRAVATED - OTHER FIREARM                                        148
#                                    AGGRAVATED POLICE OFFICER - HANDS, FISTS, FEET, NO INJURY          94
#                                    AGGRAVATED POLICE OFFICER - OTHER DANGEROUS WEAPON                 44
#                                    AGGRAVATED POLICE OFFICER - HANDGUN                                41
#                                    AGGRAVATED PROTECTED EMPLOYEE - HANDGUN                            26
#                                    AGGRAVATED PROTECTED EMPLOYEE - OTHER DANGEROUS WEAPON             24
#                                    AGGRAVATED PROTECTED EMPLOYEE - KNIFE / CUTTING INSTRUMENT         20
#                                    AGGRAVATED POLICE OFFICER - OTHER FIREARM                           6
#                                    AGGRAVATED PROTECTED EMPLOYEE - OTHER FIREARM                       6
#                                    AGGRAVATED POLICE OFFICER - KNIFE / CUTTING INSTRUMENT              5
# BATTERY                            DOMESTIC BATTERY SIMPLE                                         18636
#                                    SIMPLE                                                          13644
#                                    AGGRAVATED - HANDGUN                                             2106
#                                    AGGRAVATED - OTHER DANGEROUS WEAPON                              1618
#                                    AGGRAVATED DOMESTIC BATTERY - OTHER DANGEROUS WEAPON              970
#                                    AGG. DOMESTIC BATTERY - HANDS, FISTS, FEET, SERIOUS INJURY        803
#                                    AGGRAVATED - KNIFE / CUTTING INSTRUMENT                           690
#                                    AGGRAVATED DOMESTIC BATTERY - KNIFE / CUTTING INSTRUMENT          486
#                                    AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MINOR INJURY           434
#                                    PROTECTED EMPLOYEE - HANDS, FISTS, FEET, NO / MINOR INJURY        394
#                                    AGGRAVATED OF A SENIOR CITIZEN                                    326
#                                    AGGRAVATED - HANDS, FISTS, FEET, NO / MINOR INJURY                218
#                                    AGGRAVATED - HANDS, FISTS, FEET, SERIOUS INJURY                   130
#                                    AGGRAVATED OF A CHILD                                              78
#                                    AGGRAVATED POLICE OFFICER - OTHER DANGEROUS WEAPON                 65
#                                    AGGRAVATED P.O. - HANDS, FISTS, FEET, SERIOUS INJURY               64
#                                    AGGRAVATED PROTECTED EMPLOYEE - OTHER DANGEROUS WEAPON             53
#                                    AGG. PROTECTED EMPLOYEE - HANDS, FISTS, FEET, SERIOUS INJURY       43
#                                    AGGRAVATED DOMESTIC BATTERY - HANDGUN                              11
#                                    AGGRAVATED - OTHER FIREARM                                         11
#                                    AGGRAVATED POLICE OFFICER - HANDGUN                                 8
#                                    AGGRAVATED PROTECTED EMPLOYEE - KNIFE / CUTTING INSTRUMENT          6
#                                    OF AN UNBORN CHILD                                                  6
#                                    AGGRAVATED POLICE OFFICER - KNIFE / CUTTING INSTRUMENT              3
#                                    AGGRAVATED OF AN UNBORN CHILD                                       3
# BURGLARY                           FORCIBLE ENTRY                                                   4160
#                                    UNLAWFUL ENTRY                                                   2751
#                                    ATTEMPT FORCIBLE ENTRY                                            355
#                                    HOME INVASION                                                     298
# CONCEALED CARRY LICENSE VIOLATION  PROHIBITED PLACES                                                 105
# Name: count, dtype: int64

# %%
df.groupby(['Primary Type'])['Arrest'].value_counts(normalize=True).head(10)*100
# Out:
# Primary Type                       Arrest
# ARSON                              False     90.023753
#                                    True       9.976247
# ASSAULT                            False     90.341402
#                                    True       9.658598
# BATTERY                            False     85.460471
#                                    True      14.539529
# BURGLARY                           False     95.161290
#                                    True       4.838710
# CONCEALED CARRY LICENSE VIOLATION  True      96.045198
#                                    False      3.954802
# Name: proportion, dtype: float64

# %%
df.groupby(['Description'])['Arrest'].value_counts(normalize=True).head(10)*100
# Out:
# Description                                                   Arrest
# $500 AND UNDER                                                False      98.408245
#                                                               True        1.591755
# ABUSE / NEGLECT - CARE FACILITY                               False     100.000000
# AGG. DOMESTIC BATTERY - HANDS, FISTS, FEET, SERIOUS INJURY    False      78.953923
#                                                               True       21.046077
# AGG. PROTECTED EMPLOYEE - HANDS, FISTS, FEET, SERIOUS INJURY  False      60.465116
#                                                               True       39.534884
# AGGRAVATED                                                    False      88.282828
#                                                               True       11.717172
# AGGRAVATED - HANDGUN                                          False      90.436316
# Name: proportion, dtype: float64

# %%
df.groupby(['Primary Type'])['Arrest'].value_counts(normalize=True).tail(10)*100
# Out:
# Primary Type       Arrest
# ROBBERY            False     94.080197
#                    True       5.919803
# SEX OFFENSE        False     91.915641
#                    True       8.084359
# STALKING           False     93.473193
#                    True       6.526807
# THEFT              False     96.242424
#                    True       3.757576
# WEAPONS VIOLATION  True      61.871412
#                    False     38.128588
# Name: proportion, dtype: float64

# %%
df.groupby(['Location Description'])['Arrest'].value_counts(normalize=True).head(20)*100
# Out:
# Location Description                             Arrest
# ABANDONED BUILDING                               False     81.196581
#                                                  True      18.803419
# AIRCRAFT                                         False     94.230769
#                                                  True       5.769231
# AIRPORT BUILDING NON-TERMINAL - NON-SECURE AREA  False     87.368421
#                                                  True      12.631579
# AIRPORT BUILDING NON-TERMINAL - SECURE AREA      False     72.222222
#                                                  True      27.777778
# AIRPORT EXTERIOR - NON-SECURE AREA               False     92.857143
#                                                  True       7.142857
# AIRPORT EXTERIOR - SECURE AREA                   False     86.274510
#                                                  True      13.725490
# AIRPORT PARKING LOT                              False     95.833333
#                                                  True       4.166667
# AIRPORT TERMINAL LOWER LEVEL - NON-SECURE AREA   True      50.990099
#                                                  False     49.009901
# AIRPORT TERMINAL LOWER LEVEL - SECURE AREA       False     82.828283
#                                                  True      17.171717
# AIRPORT TERMINAL MEZZANINE - NON-SECURE AREA     False     75.000000
#                                                  True      25.000000
# Name: proportion, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 234891 entries, 0 to 239557
# Data columns (total 20 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    234891 non-null  int64
#  1   Case Number           234891 non-null  object
#  2   Date                  234891 non-null  object
#  3   Block                 234891 non-null  object
#  4   IUCR                  234891 non-null  object
#  5   Primary Type          234891 non-null  object
#  6   Description           234891 non-null  object
#  7   Location Description  234891 non-null  object
#  8   Arrest                234891 non-null  bool
#  9   Domestic              234891 non-null  bool
#  10  Beat                  234891 non-null  int64
#  11  District              234891 non-null  int64
#  12  Ward                  234891 non-null  float64
#  13  Community Area        234891 non-null  int64
#  14  FBI Code              234891 non-null  object
#  15  X Coordinate          234891 non-null  float64
#  16  Y Coordinate          234891 non-null  float64
#  17  Updated On            234891 non-null  object
#  18  Latitude              234891 non-null  float64
#  19  Longitude             234891 non-null  float64
# dtypes: bool(2), float64(5), int64(4), object(9)
# memory usage: 34.5+ MB

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Split Date & Time

# %%
def splitTime(x):
    x = x.split(" ")
    x = x[1]
    return x[0:]
df['Time'] = df['Date'].apply(splitTime)


def splitDate(x):
    x = x.split(" ")
    x = x[0]
    return x[0:]
df.Date = df.Date.apply(splitDate)

# %%
df
# Out:
#               ID Case Number        Date                   Block  IUCR  \
# 0       12592454    JF113025   1/14/2022       067XX S MORGAN ST  2826
# 1       12785595    JF346553    8/5/2022  072XX S UNIVERSITY AVE  1544
# 2       12808281    JF373517   8/14/2022     055XX W ARDMORE AVE  1562
# 3       12888104    JF469015  11/10/2022          072XX S MAY ST  1477
# 5       12622465    JF149923   2/19/2022   010XX N FRANCISCO AVE   486
# ...          ...         ...         ...                     ...   ...
# 239553     27038    JF387886    9/8/2022    061XX N WINTHROP AVE   110
# 239554     26819    JF275138   6/10/2022        018XX S CANAL ST   110
# 239555     26601    JF132803    2/3/2022        000XX E 100TH PL   110
# 239556     26857    JF290575   6/23/2022     027XX S KEDVALE AVE   110
# 239557     27015    JF377220   8/31/2022    116XX S MICHIGAN AVE   110
#
#              Primary Type                       Description  \
# 0           OTHER OFFENSE    HARASSMENT BY ELECTRONIC MEANS
# 1             SEX OFFENSE    SEXUAL EXPLOITATION OF A CHILD
# 2             SEX OFFENSE  AGGRAVATED CRIMINAL SEXUAL ABUSE
# 3       WEAPONS VIOLATION        RECKLESS FIREARM DISCHARGE
# 5                 BATTERY           DOMESTIC BATTERY SIMPLE
# ...                   ...                               ...
# 239553           HOMICIDE               FIRST DEGREE MURDER
# 239554           HOMICIDE               FIRST DEGREE MURDER
# 239555           HOMICIDE               FIRST DEGREE MURDER
# 239556           HOMICIDE               FIRST DEGREE MURDER
# 239557           HOMICIDE               FIRST DEGREE MURDER
#
#                Location Description  Arrest  Domestic  ...  District  Ward  \
# 0                         RESIDENCE   False      True  ...         7  16.0
# 1                         APARTMENT    True     False  ...         3   5.0
# 2                         RESIDENCE   False     False  ...        16  41.0
# 3                            STREET   False     False  ...         7  17.0
# 5       HOSPITAL BUILDING / GROUNDS    True      True  ...        12  26.0
# ...                             ...     ...       ...  ...       ...   ...
# 239553                        PORCH    True     False  ...        24  49.0
# 239554                       STREET   False     False  ...        12  25.0
# 239555                         AUTO   False     False  ...         5   9.0
# 239556                       STREET   False     False  ...        10  22.0
# 239557                  GAS STATION   False     False  ...         5   9.0
#
#         Community Area  FBI Code X Coordinate  Y Coordinate        Updated On  \
# 0                   68        26    1170805.0     1860170.0   9/14/2023 15:41
# 1                   69        17    1185135.0     1857211.0   9/14/2023 15:41
# 2                   11        17    1138383.0     1937953.0   9/14/2023 15:41
# 3                   68        15    1169903.0     1856822.0   9/14/2023 15:41
# 5                   24       08B    1156861.0     1906972.0   9/15/2023 15:41
# ...                ...       ...          ...           ...               ...
# 239553              77       01A    1167747.0     1940929.0  12/29/2022 15:40
# 239554              31       01A    1173423.0     1891309.0   9/19/2022 15:41
# 239555              49       01A    1178641.0     1838358.0   9/19/2022 15:41
# 239556              30       01A    1149162.0     1885416.0    9/1/2022 15:42
# 239557              53       01A    1178927.0     1827627.0   9/19/2022 15:41
#
#          Latitude  Longitude   Time
# 0       41.771782 -87.649437  15:55
# 1       41.763338 -87.597001  21:00
# 2       41.985875 -87.766404  14:00
# 3       41.762615 -87.652840   3:47
# 5       41.900506 -87.699285  10:36
# ...           ...        ...    ...
# 239553  41.993457 -87.658318  10:50
# 239554  41.857173 -87.638918  23:41
# 239555  41.711753 -87.621374  16:27
# 239556  41.841506 -87.728122   2:25
# 239557  41.682299 -87.620652   9:30
#
# [234891 rows x 21 columns]

# %% [markdown]
# ### Split Block column

# %%
def splitBlock(x):
    x = x.split(" ")
    x = x[1:]
    return " ".join(x[0:])
df.Block = df.Block.apply(splitBlock)

# %% [markdown]
# ## Encoding

# %%
columns = df[['Description','Primary Type','Location Description','Block','Date','Time']]
encoders={}
for col in columns:
    encoder = LabelEncoder()
    df[col] = encoder.fit_transform(df[col])
    encoders[col] = encoder


#joblib.dump(encoders, 'encoders.pkl')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 234891 entries, 0 to 239557
# Data columns (total 21 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    234891 non-null  int64
#  1   Case Number           234891 non-null  object
#  2   Date                  234891 non-null  int32
#  3   Block                 234891 non-null  int32
#  4   IUCR                  234891 non-null  object
#  5   Primary Type          234891 non-null  int32
#  6   Description           234891 non-null  int32
#  7   Location Description  234891 non-null  int32
#  8   Arrest                234891 non-null  bool
#  9   Domestic              234891 non-null  bool
#  10  Beat                  234891 non-null  int64
#  11  District              234891 non-null  int64
#  12  Ward                  234891 non-null  float64
#  13  Community Area        234891 non-null  int64
#  14  FBI Code              234891 non-null  object
#  15  X Coordinate          234891 non-null  float64
#  16  Y Coordinate          234891 non-null  float64
#  17  Updated On            234891 non-null  object
#  18  Latitude              234891 non-null  float64
#  19  Longitude             234891 non-null  float64
#  20  Time                  234891 non-null  int32
# dtypes: bool(2), float64(5), int32(6), int64(4), object(4)
# memory usage: 30.9+ MB

# %%
correlation_matrix = df.corr(numeric_only=True)
correlation_arrest = correlation_matrix['Arrest'].sort_values(ascending=False)
plt.figure(figsize=(8, 5))
sns.heatmap(correlation_arrest.to_frame(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation with Arrest')
plt.show()

# %% [markdown]
# # Features Selection

# %%
X = df.drop(columns=['ID','Arrest','Case Number','X Coordinate','Y Coordinate','Latitude','Longitude','IUCR','FBI Code','Community Area','Updated On']) 
y = df['Arrest']

# %%
X
# Out:
#         Date  Block  Primary Type  Description  Location Description  \
# 0          5   1384            22          129                   102
# 1        330   1510            27          227                    17
# 2        309   1805            27           13                   102
# 3         63   1362            30          214                   119
# 5        133    467             2          103                    77
# ...      ...    ...           ...          ...                   ...
# 239553   363    948            10          116                    99
# 239554   244   1069            10          116                   119
# 239555   144      0            10          116                    21
# 239556   258   1265            10          116                   119
# 239557   328   1374            10          116                    71
#
#         Domestic  Beat  District  Ward  Time
# 0           True   724         7  16.0   415
# 1          False   324         3   5.0   780
# 2          False  1621        16  41.0   300
# 3          False   733         7  17.0  1067
# 5           True  1211        12  26.0    96
# ...          ...   ...       ...   ...   ...
# 239553     False  2433        24  49.0   110
# 239554     False  1235        12  25.0   941
# 239555     False   511         5   9.0   447
# 239556     False  1031        10  22.0   985
# 239557     False   532         5   9.0  1410
#
# [234891 rows x 10 columns]

# %% [markdown]
# ## Over-Sampling of data using SMOTE

# %% [markdown]
# ### Handling Data Imbalancing

# %%
smote = SMOTE(sampling_strategy=0.75,random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# %%
y_resampled.value_counts()
# Out:
# Arrest
# False    207650
# True     155737
# Name: count, dtype: int64

# %% [markdown]
# # Data splitting

# %%
# X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,shuffle=True,random_state=57)
X_train,X_test,y_train,y_test = train_test_split(X_resampled,y_resampled,test_size=0.3,shuffle=True,random_state=57)

# %% [markdown]
# # ML Models

# %% [markdown]
# ### Best Parameters

# %%
# import optuna
# def objective(trial):
#     params = {
#         'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.1),
#         'depth': trial.suggest_int('depth', 4, 10),
#         'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1, 10),
#         'iterations': trial.suggest_int('iterations', 100, 500),
#         'subsample': trial.suggest_float('subsample', 0.8, 1.0),
#         'colsample_bylevel': trial.suggest_float('colsample_bylevel', 0.8, 1.0),
#         'random_state': 57,
#         'silent': True
#     }

   
#     model = CatBoostClassifier(**params)
#     model.fit(X_train, y_train, eval_set=(X_train, y_train), early_stopping_rounds=50, verbose=False)
#     preds = model.predict(X_train)
#     return accuracy_score(y_train, preds)


# study = optuna.create_study(direction='maximize')
# study.optimize(objective, n_trials=50)


# print("Best Parameters:", study.best_params)
# print("Best Score:", study.best_value)

# %%
models = {
    'LogisticRegression': LogisticRegression(max_iter=500),
    'SVC': SVC(kernel='rbf',C=1.0,gamma='scale',probability=True),
    'Decision Tree Classifier': DecisionTreeClassifier(splitter='best',random_state=42),
    'K-Nearest Neighbors': KNeighborsClassifier(n_neighbors=5),
    'Random Forest': RandomForestClassifier(n_estimators=200, random_state=57),
    'XGBoost': XGBClassifier(n_estimators=100,learning_rate=0.01),
    'CatBoost': CatBoostClassifier(learning_rate=0.08,depth=10,l2_leaf_reg=1.7,iterations=500, verbose=0),
    'LightGBM': LGBMClassifier(n_estimators=100, learning_rate=0.01,verbose=0)
}

results = []

for model_name, model in models.items():
    model.fit(X_train, y_train)  
    y_pred = model.predict(X_test)
    y_pred_prob = model.predict_proba(X_test)[:, 1]
    
    print(model_name)
    print("-"*10)
    
    confusion = confusion_matrix(y_test,y_pred)
    accuracy = accuracy_score(y_test,y_pred)
    percision = precision_score(y_test,y_pred)
    recall = recall_score(y_test,y_pred)
    f1 = f1_score(y_test,y_pred)
    roc = roc_auc_score(y_test,y_pred_prob)

    plt.figure(figsize=(6, 4))
    sns.heatmap(confusion, annot=True, fmt='d', cmap='Blues', linewidths=.5, cbar=False)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()

    print(classification_report(y_test,y_pred))
    results.append({
        'Model': model_name,
        'Accuracy Score': round(accuracy*100),
        'Precision': percision,
        'Recall': recall,
        'F1 Score': f1,
        'ROC-AUC': roc
    })

results_df = pd.DataFrame(results)
display(results_df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[445], line 15
#      12 results = []
#      14 for model_name, model in models.items():
# ---> 15     model.fit(X_train, y_train)
#      16     y_pred = model.predict(X_test)
#      17     y_pred_prob = model.predict_proba(X_test)[:, 1]
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:1296, in LogisticRegression.fit(self, X, y, sample_weight)
#    1293 else:
#    1294     n_threads = 1
# -> 1296 fold_coefs_ = Parallel(n_jobs=self.n_jobs, verbose=self.verbose, prefer=prefer)(
#    1297     path_func(
#    1298         X,
#    1299         y,
#    1300         pos_class=class_,
#    1301         Cs=[C_],
#    1302         l1_ratio=self.l1_ratio,
#    1303         fit_intercept=self.fit_intercept,
#    1304         tol=self.tol,
#    1305         verbose=self.verbose,
#    1306         solver=solver,
#    1307         multi_class=multi_class,
#    1308         max_iter=self.max_iter,
#    1309         class_weight=self.class_weight,
#    1310         check_input=False,
#    1311         random_state=self.random_state,
#    1312         coef=warm_start_coef_,
#    1313         penalty=penalty,
#    1314         max_squared_sum=max_squared_sum,
#    1315         sample_weight=sample_weight,
#    1316         n_threads=n_threads,
#    1317     )
#    1318     for class_, warm_start_coef_ in zip(classes_, warm_start_coef)
#    1319 )
#    1321 fold_coefs_, _, n_iter_ = zip(*fold_coefs_)
#    1322 self.n_iter_ = np.asarray(n_iter_, dtype=np.int32)[:, 0]
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\parallel.py:67, in Parallel.__call__(self, iterable)
#      62 config = get_config()
#      63 iterable_with_config = (
#      64     (_with_config(delayed_func, config), args, kwargs)
#      65     for delayed_func, args, kwargs in iterable
#      66 )
# ---> 67 return super().__call__(iterable_with_config)
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\parallel.py:1048, in Parallel.__call__(self, iterable)
#    1039 try:
#    1040     # Only set self._iterating to True if at least a batch
#    1041     # was dispatched. In particular this covers the edge
#    (...)
#    1045     # was very quick and its callback already dispatched all the
#    1046     # remaining jobs.
#    1047     self._iterating = False
# -> 1048     if self.dispatch_one_batch(iterator):
#    1049         self._iterating = self._original_iterator is not None
#    1051     while self.dispatch_one_batch(iterator):
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\parallel.py:864, in Parallel.dispatch_one_batch(self, iterator)
#     862     return False
#     863 else:
# --> 864     self._dispatch(tasks)
#     865     return True
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\parallel.py:782, in Parallel._dispatch(self, batch)
#     780 with self._lock:
#     781     job_idx = len(self._jobs)
# --> 782     job = self._backend.apply_async(batch, callback=cb)
#     783     # A job can complete so quickly than its callback is
#     784     # called before we get here, causing self._jobs to
#     785     # grow. To ensure correct results ordering, .insert is
#     786     # used (rather than .append) in the following line
#     787     self._jobs.insert(job_idx, job)
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\parallel.py:263, in BatchedCalls.__call__(self)
#     259 def __call__(self):
#     260     # Set the default nested backend to self._backend but do not set the
#     261     # change the default number of processes to -1
#     262     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263         return [func(*args, **kwargs)
#     264                 for func, args, kwargs in self.items]
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\parallel.py:129, in _FuncWrapper.__call__(self, *args, **kwargs)
#     127     config = {}
#     128 with config_context(**config):
# --> 129     return self.function(*args, **kwargs)
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:455, in _logistic_regression_path(X, y, pos_class, Cs, fit_intercept, max_iter, tol, verbose, solver, coef, class_weight, dual, penalty, intercept_scaling, multi_class, random_state, check_input, max_squared_sum, sample_weight, l1_ratio, n_threads)
#     451 l2_reg_strength = 1.0 / (C * sw_sum)
#     452 iprint = [-1, 50, 1, 100, 101][
#     453     np.searchsorted(np.array([0, 1, 2, 3]), verbose)
#     454 ]
# --> 455 opt_res = optimize.minimize(
#     456     func,
#     457     w0,
#     458     method="L-BFGS-B",
#     459     jac=True,
#     460     args=(X, target, sample_weight, l2_reg_strength, n_threads),
#     461     options={
#     462         "maxiter": max_iter,
#     463         "maxls": 50,  # default is 20
#     464         "iprint": iprint,
#     465         "gtol": tol,
#     466         "ftol": 64 * np.finfo(float).eps,
#     467     },
#     468 )
#     469 n_iter_i = _check_optimize_result(
#     470     solver,
#     471     opt_res,
#     472     max_iter,
#     473     extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
#     474 )
#     475 w0, loss = opt_res.x, opt_res.fun
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\optimize\_minimize.py:710, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     707     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     708                              **options)
#     709 elif meth == 'l-bfgs-b':
# --> 710     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     711                            callback=callback, **options)
#     712 elif meth == 'tnc':
#     713     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     714                         **options)
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\optimize\_lbfgsb_py.py:365, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     359 task_str = task.tobytes()
#     360 if task_str.startswith(b'FG'):
#     361     # The minimization routine wants f and g at the current x.
#     362     # Note that interruptions due to maxfun are postponed
#     363     # until the completion of the current minimization iteration.
#     364     # Overwrite f and g:
# --> 365     f, g = func_and_grad(x)
#     366 elif task_str.startswith(b'NEW_X'):
#     367     # new iteration
#     368     n_iterations += 1
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\optimize\_differentiable_functions.py:285, in ScalarFunction.fun_and_grad(self, x)
#     283 if not np.array_equal(x, self.x):
#     284     self._update_x_impl(x)
# --> 285 self._update_fun()
#     286 self._update_grad()
#     287 return self.f, self.g
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\optimize\_differentiable_functions.py:251, in ScalarFunction._update_fun(self)
#     249 def _update_fun(self):
#     250     if not self.f_updated:
# --> 251         self._update_fun_impl()
#     252         self.f_updated = True
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\optimize\_differentiable_functions.py:155, in ScalarFunction.__init__.<locals>.update_fun()
#     154 def update_fun():
# --> 155     self.f = fun_wrapped(self.x)
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\optimize\_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     133 self.nfev += 1
#     134 # Send a copy because the user may overwrite it.
#     135 # Overwriting results in undefined behaviour because
#     136 # fun(self.x) will change self.x, with the two no longer linked.
# --> 137 fx = fun(np.copy(x), *args)
#     138 # Make sure the function returns a true scalar
#     139 if not np.isscalar(fx):
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\optimize\_optimize.py:77, in MemoizeJac.__call__(self, x, *args)
#      75 def __call__(self, x, *args):
#      76     """ returns the function value """
# ---> 77     self._compute_if_needed(x, *args)
#      78     return self._value
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\optimize\_optimize.py:71, in MemoizeJac._compute_if_needed(self, x, *args)
#      69 if not np.all(x == self.x) or self._value is None or self.jac is None:
#      70     self.x = np.asarray(x).copy()
# ---> 71     fg = self.fun(x, *args)
#      72     self.jac = fg[1]
#      73     self._value = fg[0]
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_linear_loss.py:280, in LinearModelLoss.loss_gradient(self, coef, X, y, sample_weight, l2_reg_strength, n_threads, raw_prediction)
#     277 else:
#     278     weights, intercept = self.weight_intercept(coef)
# --> 280 loss, grad_pointwise = self.base_loss.loss_gradient(
#     281     y_true=y,
#     282     raw_prediction=raw_prediction,
#     283     sample_weight=sample_weight,
#     284     n_threads=n_threads,
#     285 )
#     286 sw_sum = n_samples if sample_weight is None else np.sum(sample_weight)
#     287 loss = loss.sum() / sw_sum
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\_loss\loss.py:254, in BaseLoss.loss_gradient(self, y_true, raw_prediction, sample_weight, loss_out, gradient_out, n_threads)
#     251 if gradient_out.ndim == 2 and gradient_out.shape[1] == 1:
#     252     gradient_out = gradient_out.squeeze(1)
# --> 254 self.closs.loss_gradient(
#     255     y_true=y_true,
#     256     raw_prediction=raw_prediction,
#     257     sample_weight=sample_weight,
#     258     loss_out=loss_out,
#     259     gradient_out=gradient_out,
#     260     n_threads=n_threads,
#     261 )
#     262 return loss_out, gradient_out
#
# KeyboardInterrupt:

# %%
model = CatBoostClassifier(learning_rate=0.08,depth=10,l2_leaf_reg=1.7,iterations=500, verbose=0)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
y_pred_prob = model.predict_proba(X_test)[:, 1]


acc = accuracy_score(y_test,y_pred)
confusion = confusion_matrix(y_test,y_pred)
classification_rep = classification_report(y_test,y_pred)
roc = roc_auc_score(y_test,y_pred_prob)


print(f'{round(acc*100)}%')
print(confusion)
print(classification_rep)
print(f'{round(roc*100)}%')


plt.figure(figsize=(6, 4))
sns.heatmap(confusion, annot=True, fmt='d', cmap='Blues', linewidths=.5, cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()


# Save the model to a file
#joblib.dump(model, 'Catboost_model.pkl')
#print("Model saved successfully!")
# Out:
# 94%
# [[60866  1202]
#  [ 5409 41540]]
#               precision    recall  f1-score   support
#
#        False       0.92      0.98      0.95     62068
#         True       0.97      0.88      0.93     46949
#
#     accuracy                           0.94    109017
#    macro avg       0.95      0.93      0.94    109017
# weighted avg       0.94      0.94      0.94    109017
#
# 98%

# %% [markdown]
# # GUI

# %%
import tkinter as tk
from tkinter import ttk
from datetime import datetime
import joblib

# Load encoders and model
encoders = joblib.load('encoders.pkl')
model = joblib.load('Catboost_model.pkl')

def predict():
    try:
        # Collect inputs
        description = description_var.get()
        primary_type = primary_type_var.get()
        location_description = location_description_var.get()
        block = block_var.get()
        domestic = 1 if domestic_var.get().lower() == "true" else 0
        ward = float(ward_var.get())
        date = date_var.get()
        district = float(district_var.get())
        beat = float(beat_var.get())
        time = time_var.get()

        # Handle date and time conversion
        try:
            time_parsed = datetime.strptime(time, "%H:%M")
        except ValueError as e:
            result_label.config(text=f"Invalid time format. Please use HH:MM. Error: {e}")
            return

        # Encode categorical inputs using the loaded encoders
        date_encoded = encoders['Date'].transform([date])[0]
        description_encoded = encoders['Description'].transform([description])[0]
        primary_type_encoded = encoders['Primary Type'].transform([primary_type])[0]
        location_description_encoded = encoders['Location Description'].transform([location_description])[0]
        block_encoded = encoders['Block'].transform([block])[0]
        time_encoded = encoders['Time'].transform([time])[0]

        # Prepare input for the model
        encoded_inputs = [
            date_encoded,
            block_encoded,
            primary_type_encoded,
            description_encoded,
            location_description_encoded,
            domestic,
            beat,
            district,
            ward,
            time_encoded
        ]
        prediction = model.predict([encoded_inputs])[0]
        probabilities = model.predict_proba([encoded_inputs])[0][1] 
        probabilities = round(probabilities, 2)  

        result_label.config(text=f'Prediction: {prediction}\nProbability: {probabilities}')

    except Exception as e:
        result_label.config(text=f"Error: {e}")

# Create GUI window
root = tk.Tk()
root.title("Crime Prediction System")
root.geometry("500x600")

# Apply a theme
style = ttk.Style(root)
style.theme_use("clam")
style.configure("TLabel", font=("Arial", 12))
style.configure("TButton", font=("Arial", 12))
style.configure("TEntry", font=("Arial", 12))

# Create a main frame for padding
main_frame = ttk.Frame(root, padding=(20, 20, 20, 20))
main_frame.pack(fill="both", expand=True)

# Title label
title_label = ttk.Label(main_frame, text="Crime Prediction System", font=("Arial", 16, "bold"))
title_label.pack(pady=10)

# Input fields frame
input_frame = ttk.Frame(main_frame)
input_frame.pack(fill="x", pady=10)

description_var = tk.StringVar()
primary_type_var = tk.StringVar()
location_description_var = tk.StringVar()
block_var = tk.StringVar()
domestic_var = tk.StringVar()
ward_var = tk.StringVar()
date_var = tk.StringVar()
district_var = tk.StringVar()
beat_var = tk.StringVar()
time_var = tk.StringVar()

fields = [
    ('Description', description_var),
    ('Primary Type', primary_type_var),
    ('Location Description', location_description_var),
    ('Block', block_var),
    ('Domestic', domestic_var),
    ('Ward', ward_var),
    ('Date', date_var),
    ('District', district_var),
    ('Beat', beat_var),
    ('Time (HH:MM)', time_var)
]

for i, (label, var) in enumerate(fields):
    ttk.Label(input_frame, text=label).grid(row=i, column=0, padx=10, pady=5, sticky='w')
    ttk.Entry(input_frame, textvariable=var).grid(row=i, column=1, padx=10, pady=5)

# Predict button
button_frame = ttk.Frame(main_frame)
button_frame.pack(fill="x", pady=20)

predict_button = ttk.Button(button_frame, text="Predict", command=predict)
predict_button.pack()

# Result label
result_frame = ttk.Frame(main_frame, padding=(10, 10, 10, 10))
result_frame.pack(fill="x", pady=10)

result_label = ttk.Label(result_frame, text="Prediction will appear here.", font=("Arial", 12), anchor="center")
result_label.pack()

root.mainloop()
